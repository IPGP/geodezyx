# %% [markdown]
# ### Import the librairies

# %%
#### Import star style
from geodezyx import *                   # Import the GeodeZYX modules
from geodezyx.externlib import *         # Import the external modules
from geodezyx.megalib.megalib import *   # Import the legacy modules names

# %% [markdown]
# ### Read TimeSeries

# %% [markdown]
# We take Nevada Geodetic Laboratory's Time Series as exemple. But the GeodeZYX Toolbox can handle a lot of formats. See the documentation for more details.

# %%
#### file path of the ENU coordinates
exemple_dir = "/home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples"
p_nevada_xyz = exemple_dir + "/POTS.txyz2"
#### Import the time series
TS = files_rw.read_nevada(p_nevada_xyz,"xyz")

# %% [markdown]
# Data are imported in a TimeSeries object. Let's see what we can do with it.

# %% [markdown]
# ### Access the coordinates

# %% [markdown]
# #### Get the number of points

# %%
TS.nbpts
# Out:
# 9164

# %% [markdown]
# #### Get the mean position

# %%
TS.mean_posi()
# Out:
# 3800689.5741839134,882077.4431790974,5028791.352136894,1983-01-10 17:37:40.800000,411068260.8000005

# %% [markdown]
# #### Get a random point

# %%
TS.aleapt()
# Out:
# INFO: point no 7891
# 3800689.42176239,882077.589792106,5028791.43638528,2017-11-27 12:10:48.000002,1511784648.000002

# %% [markdown]
# #### As lists: X,Y,Z,T in posix time, sigmaX, sigmaY, sigmaZ

# %%
TS.to_list()
# Out:
# (array([3800689.8576985 , 3800689.84942559, 3800689.85474871, ...,
#         3800689.37356857, 3800689.36910707, 3800689.37206624]),
#  array([882077.24751725, 882077.24649048, 882077.24343861, ...,
#         882077.65042637, 882077.64960182, 882077.65033033]),
#  array([5028791.23577674, 5028791.23032963, 5028791.23343876, ...,
#         5028791.47859444, 5028791.47265105, 5028791.47668135]),
#  array([8.00769629e+08, 8.00854776e+08, 8.00939923e+08, ...,
#         1.62273270e+09, 1.62282100e+09, 1.62290615e+09]),
#  array([0.00231003, 0.00257545, 0.00233404, ..., 0.00233694, 0.00228989,
#         0.00240093]),
#  array([0.00094405, 0.00105486, 0.00096165, ..., 0.00097792, 0.00094515,
#         0.00100313]),
#  array([0.00271395, 0.00303863, 0.00272433, ..., 0.00294439, 0.00279221,
#         0.00295169]))

# %% [markdown]
# #### As a DataFrame (recommended)

# %%
TS.to_dataframe()
# Out:
#                             Tdt            T            X       Y  \
# 0    1995-05-18 04:00:28.800001   8.0077e+08  3.80069e+06  882077
# 1    1995-05-19 03:39:36.000001  8.00855e+08  3.80069e+06  882077
# 2    1995-05-20 03:18:43.200001   8.0094e+08  3.80069e+06  882077
# 3    1995-05-21 03:50:24.000000  8.01028e+08  3.80069e+06  882077
# 4    1995-05-22 03:29:31.200001  8.01113e+08  3.80069e+06  882077
# ...                         ...          ...          ...     ...
# 9159 2021-06-01 15:46:48.000002  1.62256e+09  3.80069e+06  882078
# 9160 2021-06-02 15:25:55.200002  1.62265e+09  3.80069e+06  882078
# 9161 2021-06-03 15:05:02.400002  1.62273e+09  3.80069e+06  882078
# 9162 2021-06-04 15:36:43.200002  1.62282e+09  3.80069e+06  882078
# 9163 2021-06-05 15:15:50.400002  1.62291e+09  3.80069e+06  882078
#
#                 Z          sX           sY          sZ
# 0     5.02879e+06  0.00231003  0.000944047  0.00271395
# 1     5.02879e+06  0.00257545   0.00105486  0.00303863
# 2     5.02879e+06  0.00233404  0.000961652  0.00272433
# 3     5.02879e+06  0.00232557  0.000952926  0.00267102
# 4     5.02879e+06  0.00225938  0.000970631  0.00278897
# ...           ...         ...          ...         ...
# 9159  5.02879e+06  0.00228744  0.000940509  0.00277635
# 9160  5.02879e+06  0.00236903  0.000979014  0.00290255
# 9161  5.02879e+06  0.00233694  0.000977922  0.00294439
# 9162  5.02879e+06  0.00228989  0.000945148  0.00279221
# 9163  5.02879e+06  0.00240093   0.00100313  0.00295169
#
# [9164 rows x 8 columns]

# %% [markdown]
# #### As DataFrame, but with geographic coordinates

# %%
TS.to_dataframe('FLH') ### F: Phi, L:Lambda, H: Height
# Out:
#                             Tdt            T        F        L        H   sF  \
# 0    1995-05-18 04:00:28.800001   8.0077e+08  52.3793  13.0661  144.467  NaN
# 1    1995-05-19 03:39:36.000001  8.00855e+08  52.3793  13.0661  144.457  NaN
# 2    1995-05-20 03:18:43.200001   8.0094e+08  52.3793  13.0661  144.462  NaN
# 3    1995-05-21 03:50:24.000000  8.01028e+08  52.3793  13.0661  144.444  NaN
# 4    1995-05-22 03:29:31.200001  8.01113e+08  52.3793  13.0661  144.404  NaN
# ...                         ...          ...      ...      ...      ...  ...
# 9159 2021-06-01 15:46:48.000002  1.62256e+09  52.3793  13.0661   144.43  NaN
# 9160 2021-06-02 15:25:55.200002  1.62265e+09  52.3793  13.0661  144.428  NaN
# 9161 2021-06-03 15:05:02.400002  1.62273e+09  52.3793  13.0661  144.427  NaN
# 9162 2021-06-04 15:36:43.200002  1.62282e+09  52.3793  13.0661  144.419  NaN
# 9163 2021-06-05 15:15:50.400002  1.62291e+09  52.3793  13.0661  144.424  NaN
#
#        sL   sH
# 0     NaN  NaN
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# ...   ...  ...
# 9159  NaN  NaN
# 9160  NaN  NaN
# 9161  NaN  NaN
# 9162  NaN  NaN
# 9163  NaN  NaN
#
# [9164 rows x 8 columns]

# %% [markdown]
# ### Determine the East North Up coordinates

# %% [markdown]
# #### w.r.t. mean position

# %%
TS.ENUcalc_from_mean_posi()

# %% [markdown]
# #### w.r.t. a ref position

# %%
pt_ref = time_series.Point(3800689.6341,882077.3857,5028791.3179 ,2008.0,"XYZ")
TS.ENUcalc(pt_ref)

# %% [markdown]
# #### Now we can access to the ENU coordinates

# %%
TS.to_dataframe('ENU') ### F: Phi, L:Lambda, H: Height
# Out:
#                             Tdt            T         E         N           U  \
# 0    1995-05-18 04:00:28.800001   8.0077e+08 -0.185155 -0.197907   0.0488408
# 1    1995-05-19 03:39:36.000001  8.00855e+08 -0.184285 -0.194665   0.0394653
# 2    1995-05-20 03:18:43.200001   8.0094e+08 -0.188461 -0.196328   0.0446721
# 3    1995-05-21 03:50:24.000000  8.01028e+08 -0.185486 -0.194254   0.0260361
# 4    1995-05-22 03:29:31.200001  8.01113e+08 -0.183354 -0.151818  -0.0135891
# ...                         ...          ...       ...       ...         ...
# 9159 2021-06-01 15:46:48.000002  1.62256e+09  0.313917  0.251095    0.012498
# 9160 2021-06-02 15:25:55.200002  1.62265e+09  0.315644  0.252412   0.0102647
# 9161 2021-06-03 15:05:02.400002  1.62273e+09  0.316772  0.251705  0.00889509
# 9162 2021-06-04 15:36:43.200002  1.62282e+09  0.316978  0.251667  0.00142079
# 9163 2021-06-05 15:15:50.400002  1.62291e+09  0.317018  0.251714  0.00647321
#
#               sE          sN          sU
# 0     0.00105755  0.00243924  0.00255435
# 1     0.00118104  0.00272487  0.00285643
# 2     0.00107515  0.00245731  0.00256908
# 3      0.0010668  0.00243046   0.0025309
# 4     0.00107465  0.00244286  0.00258899
# ...          ...         ...         ...
# 9159  0.00105203  0.00245265  0.00258897
# 9160  0.00109377  0.00255168  0.00269966
# 9161   0.0010893  0.00255192  0.00271812
# 9162  0.00105624  0.00246076  0.00260045
# 9163  0.00111779  0.00259044  0.00274287
#
# [9164 rows x 8 columns]

# %% [markdown]
# ### Plot The TimeSeries

# %%
TS.plot('ENU')
# Out:
# plot : 9164 pts,  POTS

# %% [markdown]
# ### Clean the outliers from the TimeSeries

# %% [markdown]
# #### Based on high sigmas

# %%
std_val_lim = 0.005 ### exclude point with std higher than 5mm (exemple)
coords_type = 'ENU'
TSclean = time_series.std_dev_cleaner(TS,std_val_lim,coords_type,verbose=True)
# Out:
# INFO : std_dev_cleaner : POTS clean ratio 9164 9153 0.9988

# %% [markdown]
# #### Based on MAD detection

# %%
TSclean = time_series.mad_cleaner(TSclean,coortype=coords_type,detrend_first=True,verbose=True)
# Out:
# ENU
# WARNING: you use outiler_mad,with a typo in the name !!!
#          you should use outlier_mad instead          !!!
# INFO : mad_cleaner : POTS clean ratio 8933 8923 0.9989

# %% [markdown]
# ### Shorten a TimeSeries

# %% [markdown]
# We keep 2 windows: 2000-2005 and 2010 until the last epoch

# %%
TSshort = time_series.time_win(TSclean,[(dt.datetime(2000,1,1),dt.datetime(2005,12,31)),
                                        (dt.datetime(2010,1,1),dt.datetime(2099,12,1))])
# Out:
# POTS 8923 points 1995-05-22 03:29:31.200001 2021-06-05 15:15:50.400002 9512 nb days 93.81%
# windows 0
# 2000-01-01 00:00:00 2005-12-31 00:00:00
# windows 1
# 2010-01-01 00:00:00 2099-12-01 00:00:00

# %% [markdown]
# ### Add discontinuities

# %% [markdown]
# #### Extract the discontinuities from the Sitelogs

# %%
Ant_dico = dict()
Rec_dico = dict()

ls = exemple_dir + '/pots_20210215.log'

#### Read the Site name, Receiver blocks, and Antenna Blocks
Site     = gfc.read_blocks_logsheet(ls,1)
Rec_list = gfc.read_blocks_logsheet(ls,3)
Ant_list = gfc.read_blocks_logsheet(ls,4)
    
Rec_dico[Site[0].Four_Character_ID] = Rec_list
Ant_dico[Site[0].Four_Character_ID] = Ant_list

# %%
#### Extract the discontinuities epochs
Discont_Rec = [Rec.Date_Installed for Rec in Rec_dico[TSshort.stat]]
Discont_Ant = [Ant.Date_Installed for Ant in Ant_dico[TSshort.stat]]
        
Discont = sorted(Discont_Rec + Discont_Ant)

# %% [markdown]
# #### Apply the discontinuities to the TimeSeries

# %%
TSshort.set_discont(Discont)

# %% [markdown]
# ### Plot the result

# %%
TSshort.plot("ENU")
TSshort.plot_discont()
# Out:
# plot : 6102 pts,  POTS

# %% [markdown]
# ### Export

# %% [markdown]
# #### Export content in an HECTOR's compatible NEU file

# %%
export_path_hector = exemple_dir
time_series.export_ts_as_neu(TSshort, export_path_hector , "",coordtype=coords_type)
# Out:
# INFO : timeserie exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.neu

# %% [markdown]
# #### Export content in an MIDAS's compatible TNEU file

# %%
export_path_midas = exemple_dir
time_series.export_ts_as_midas_tenu(TSshort, export_path_midas , "",coordtype=coords_type)
# Out:
# INFO : timeserie exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.tenu
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
# INFO : timeserie discont. (steps) exported in /home/psakicki/CODES/GeodeZYX-Toolbox_v4/geodezyx/000_exemples/timeseries_reader/exemples/POTS.step
